# %% [markdown]
# <a href="https://colab.research.google.com/github/showblue/ai-agent-foundation-labs/blob/main/A_Simple_Chain_with_Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Install required packages
# !pip install -qU langchain langchain-google-genai google-generativeai==0.8.5
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.4 MB/s eta 0:00:00

# %%
import os, sys, platform
from google.colab import userdata
from datetime import datetime

# LangChain + Gemini
import langchain, langchain_core
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.schema.output_parser import StrOutputParser
from langchain.schema.runnable import RunnablePassthrough

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#  Set your Gemini API key
os.environ["GOOGLE_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %%
# Recommended for demos: fast & economical
model_name = "gemini-2.0-flash"

llm = ChatGoogleGenerativeAI(
    model=model_name,
    convert_system_message_to_human=True,  # smoother behavior with system prompts
    temperature=0.7,
)
print(f" Ready with model: {model_name}")
# Out:
#  Ready with model: gemini-2.0-flash

# %%
# First LLM call.
msg = "Explain AI in one friendly paragraph for a complete beginner."
resp = llm.invoke(msg)   # ChatModels accept a plain string or list of messages
print(resp.content)
# Out:
# Imagine teaching a computer to think and learn like a human, but instead of teaching it directly, you give it lots of examples. That's essentially what AI is! It's a way of creating computer programs that can analyze information, recognize patterns, make decisions, and even solve problems, all without needing to be explicitly programmed for every single situation. Think of it like training a dog - you show it what you want and reward it when it gets it right, and over time, it learns to do it on its own. AI uses similar principles to learn from data and become "intelligent" in specific areas.

# %% [markdown]
# # PromptTemplate → Chain (Runnable)

# %%
# Build a motivational quote generator with a parameterized prompt
motivation_prompt = PromptTemplate.from_template(
    "Write a short, uplifting motivational quote for someone working as a {profession}. "
    "Keep it under 25 words."
)

# %%
# Compose: Prompt → LLM → String output
chain = motivation_prompt | llm | StrOutputParser()

# %%
print(" Example (profession=teacher):")
print(chain.invoke({"profession": "teacher"}))
# Out:
#  Example (profession=teacher):
# You're planting seeds of knowledge and shaping futures. Your impact is immeasurable. Keep shining!

# %% [markdown]
# # Quick Playground helper

# %%
def ask(prompt: str):
    """Mini helper to chat with the model."""
    res = llm.invoke(prompt)
    return res.content

print(ask("Give me 3 icebreakers to start a workshop on AI for Beginners."))
# Out:
# Okay, here are 3 icebreaker options for an AI for Beginners workshop, designed to be engaging and accessible even to those with no prior knowledge:
#
# **1.  "AI in Your Pocket"**
#
# *   **Objective:**  To get participants thinking about how AI already impacts their daily lives and to surface common examples.
# *   **Instructions:**
#     *   **(Individually, 2 minutes):**  Think about your smartphone or other devices you use regularly. List 2-3 ways you think you might be interacting with AI (even if you're not sure it's *really* AI).
#     *   **(Small Groups, 5 minutes):**  Share your lists with 2-3 other people.  Identify common examples and note any surprising or unexpected uses of AI that came up.
#     *   **(Whole Group Share, 5 minutes):**  Facilitator asks groups to share their most common and most surprising examples.  Write these on a whiteboard or flip chart.
# *   **Why it works:**  Everyone uses technology, so everyone can participate. It's non-threatening and starts with concrete examples.  It also creates a shared understanding of what AI *might* be.
#
# **2.  "AI Wish List"**
#
# *   **Objective:**  To tap into participants' imaginations and get them thinking about the *potential* of AI to solve problems or improve lives.
# *   **Instructions:**
#     *   **(Individually, 3 minutes):**  Imagine you have access to perfect AI. What is one problem (big or small, personal or global) that you would want AI to solve? Describe the problem and how the AI would ideally address it.
#     *   **(Pair Share, 5 minutes):**  Share your "AI wish" with a partner. Discuss the potential benefits and any potential ethical concerns that might arise.
#     *   **(Optional Whole Group Share, 5 minutes):**  Facilitator can ask a few volunteers to share their wishes with the larger group.
# *   **Why it works:**  This is a more creative and future-oriented icebreaker. It encourages blue-sky thinking and surfaces potential applications of AI that might be personally meaningful to participants.  The ethical considerations component subtly introduces an important aspect of AI.
#
# **3. "Two Truths and a Lie: AI Edition"**
#
# *   **Objective:**  To uncover some common misconceptions about AI and to encourage discussion about what AI *is* and *is not*.
# *   **Instructions:**
#     *   **(Individually, 3 minutes):**  Write down three statements about AI. Two should be true, and one should be a lie (or a common misconception).  Make them believable!
#     *   **(Small Groups, 5 minutes):**  Take turns reading your statements to your group.  The group has to guess which statement is the lie.
#     *   **(Whole Group Debrief, 5 minutes):**  Facilitator asks a few groups to share some of their truths and lies, and the group's guesses.  Use this as an opportunity to clarify common misconceptions and reinforce basic AI concepts.
# *   **Why it works:**  This is a fun and interactive icebreaker that gets people actively thinking about AI. It also allows the facilitator to address misconceptions early on and set the stage for more accurate learning.  This is a great way to start the conversation.
#
# **Important Considerations for ALL Icebreakers:**
#
# *   **Keep it short:** Icebreakers shouldn't take up too much time.
# *   **Make it inclusive:** Choose activities that everyone can participate in, regardless of their background or experience.
# *   **Explain the purpose:** Briefly explain why you're doing the icebreaker (e.g., "to get us thinking about how AI is already part of our lives").
# *   **Be enthusiastic:** Your energy will set the tone for the workshop.
# *   **Timebox:** Stick to the allotted time for each step.
# *   **Debrief:**  Always take a few minutes to debrief the activity and connect it to the workshop content.
#
# Choose the icebreaker that best suits the overall tone and objectives of your workshop.  Good luck!
